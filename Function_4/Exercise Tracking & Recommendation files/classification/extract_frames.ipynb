# %%
import cv2
import os

# %%
def extract_frames_from_video(video_path, output_folder, frame_rate=1):
    """
    Extract frames from a video and save them into a folder.

    Parameters:
        video_path (str): Path to the input video.
        output_folder (str): Path to the folder where frames will be saved.
        frame_rate (int): Interval of frames to save (e.g., 1 saves every frame, 2 saves every 2nd frame).
    """
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    cap = cv2.VideoCapture(video_path)
    frame_count = 0
    saved_count = 0

    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break

        if frame_count % frame_rate == 0:
            frame_filename = os.path.join(output_folder, f"frame_{saved_count:04d}.jpg")
            cv2.imwrite(frame_filename, frame)
            saved_count += 1

        frame_count += 1

    cap.release()
    print(f"Frames extracted and saved to: {output_folder}")

# %%
def process_videos_in_folder(input_folder, output_folder_base, frame_rate=1):
    """
    Process all videos in a folder and extract frames for each class.

    Parameters:
        input_folder (str): Path to the folder containing class subfolders with videos.
        output_folder_base (str): Path to the base folder for saving extracted frames.
        frame_rate (int): Interval of frames to save.
    """
    for class_name in os.listdir(input_folder):
        class_folder = os.path.join(input_folder, class_name)
        if not os.path.isdir(class_folder):
            continue

        output_class_folder = os.path.join(output_folder_base, class_name)
        for video_file in os.listdir(class_folder):
            video_path = os.path.join(class_folder, video_file)
            if video_file.endswith(('.mp4', '.avi', '.mov')):
                video_output_folder = os.path.join(output_class_folder, os.path.splitext(video_file)[0])
                extract_frames_from_video(video_path, video_output_folder, frame_rate)

# %%
input_folder = "/content/drive/MyDrive/Exercise Tracking/exercise_videos"
output_folder_base = "/content/drive/MyDrive/Exercise Tracking/frames"
frame_rate = 10

process_videos_in_folder(input_folder, output_folder_base, frame_rate)
# Out:
# Frames extracted and saved to: /content/drive/MyDrive/Exercise Tracking/frames/Seated Neck Flexion/Seated_Neck_Flexion_7
# Frames extracted and saved to: /content/drive/MyDrive/Exercise Tracking/frames/Seated Neck Flexion/Seated_Neck_Flexion_8
# Frames extracted and saved to: /content/drive/MyDrive/Exercise Tracking/frames/Seated Neck Flexion/Seated_Neck_Flexion_1
# Frames extracted and saved to: /content/drive/MyDrive/Exercise Tracking/frames/Seated Neck Flexion/Seated_Neck_Flexion_2
# Frames extracted and saved to: /content/drive/MyDrive/Exercise Tracking/frames/Seated Neck Flexion/Seated_Neck_Flexion_3
# Frames extracted and saved to: /content/drive/MyDrive/Exercise Tracking/frames/Seated Neck Flexion/Seated_Neck_Flexion_4
# Frames extracted and saved to: /content/drive/MyDrive/Exercise Tracking/frames/Seated Neck Flexion/Seated_Neck_Flexion_5
# Frames extracted and saved to: /content/drive/MyDrive/Exercise Tracking/frames/Seated Neck Flexion/Seated_Neck_Flexion_6
# Frames extracted and saved to: /content/drive/MyDrive/Exercise Tracking/frames/Seated Neck Flexion/Seated_Neck_Flexion_9
# Frames extracted and saved to: /content/drive/MyDrive/Exercise Tracking/frames/Neck Side Bend/Neck_Side_Bend_5
# Frames extracted and saved to: /content/drive/MyDrive/Exercise Tracking/frames/Neck Side Bend/Neck_Side_Bend_6
# Frames extracted and saved to: /content/drive/MyDrive/Exercise Tracking/frames/Neck Side Bend/Neck_Side_Bend_1
# Frames extracted and saved to: /content/drive/MyDrive/Exercise Tracking/frames/Neck Side Bend/Neck_Side_Bend_2
# Frames extracted and saved to: /content/drive/MyDrive/Exercise Tracking/frames/Neck Side Bend/Neck_Side_Bend_3
# Frames extracted and saved to: /content/drive/MyDrive/Exercise Tracking/frames/Neck Side Bend/Neck_Side_Bend_4
# Frames extracted and saved to: /content/drive/MyDrive/Exercise Tracking/frames/Neck Side Bend/Neck_Side_Bend_7
# Frames extracted and saved to: /content/drive/MyDrive/Exercise Tracking/frames/Neck Side Bend/Neck_Side_Bend_8
# Frames extracted and saved to: /content/drive/MyDrive/Exercise Tracking/frames/Shoulder Shrugs/Shoulder_Shrugs_6
# Frames extracted and saved to: /content/drive/MyDrive/Exercise Tracking/frames/Shoulder Shrugs/Shoulder_Shrugs_1
# Frames extracted and saved to: /content/drive/MyDrive/Exercise Tracking/frames/Shoulder Shrugs/Shoulder_Shrugs_2
# Frames extracted and saved to: /content/drive/MyDrive/Exercise Tracking/frames/Shoulder Shrugs/Shoulder_Shrugs_3
# Frames extracted and saved to: /content/drive/MyDrive/Exercise Tracking/frames/Shoulder Shrugs/Shoulder_Shrugs_4
# Frames extracted and saved to: /content/drive/MyDrive/Exercise Tracking/frames/Shoulder Shrugs/Shoulder_Shrugs_7
# Frames extracted and saved to: /content/drive/MyDrive/Exercise Tracking/frames/Shoulder Shrugs/Shoulder_Shrugs_8
# Frames extracted and saved to: /content/drive/MyDrive/Exercise Tracking/frames/Seated Head Turns/Seated_Head_Turns_5
# Frames extracted and saved to: /content/drive/MyDrive/Exercise Tracking/frames/Seated Head Turns/Seated_Head_Turns_6
# Frames extracted and saved to: /content/drive/MyDrive/Exercise Tracking/frames/Seated Head Turns/Seated_Head_Turns_1
# Frames extracted and saved to: /content/drive/MyDrive/Exercise Tracking/frames/Seated Head Turns/Seated_Head_Turns_2
# Frames extracted and saved to: /content/drive/MyDrive/Exercise Tracking/frames/Seated Head Turns/Seated_Head_Turns_3
# Frames extracted and saved to: /content/drive/MyDrive/Exercise Tracking/frames/Seated Head Turns/Seated_Head_Turns_4
# Frames extracted and saved to: /content/drive/MyDrive/Exercise Tracking/frames/Seated Head Turns/Seated_Head_Turns_7
# Frames extracted and saved to: /content/drive/MyDrive/Exercise Tracking/frames/Seated Head Turns/Seated_Head_Turns_8
# Frames extracted and saved to: /content/drive/MyDrive/Exercise Tracking/frames/Seated Neck Stretch/Seated_Neck_Stretch_7
# Frames extracted and saved to: /content/drive/MyDrive/Exercise Tracking/frames/Seated Neck Stretch/Seated_Neck_Stretch_6
# Frames extracted and saved to: /content/drive/MyDrive/Exercise Tracking/frames/Seated Neck Stretch/Seated_Neck_Stretch_1
# Frames extracted and saved to: /content/drive/MyDrive/Exercise Tracking/frames/Seated Neck Stretch/Seated_Neck_Stretch_2
# Frames extracted and saved to: /content/drive/MyDrive/Exercise Tracking/frames/Seated Neck Stretch/Seated_Neck_Stretch_3
# Frames extracted and saved to: /content/drive/MyDrive/Exercise Tracking/frames/Seated Neck Stretch/Seated_Neck_Stretch_4
# Frames extracted and saved to: /content/drive/MyDrive/Exercise Tracking/frames/Seated Neck Stretch/Seated_Neck_Stretch_5
# Frames extracted and saved to: /content/drive/MyDrive/Exercise Tracking/frames/Seated Neck Stretch/Seated_Neck_Stretch_8
# Frames extracted and saved to: /content/drive/MyDrive/Exercise Tracking/frames/Seated Neck Stretch/Seated_Neck_Stretch_9
# Frames extracted and saved to: /content/drive/MyDrive/Exercise Tracking/frames/Neck Isometrics/Neck_Isometrics_6
# Frames extracted and saved to: /content/drive/MyDrive/Exercise Tracking/frames/Neck Isometrics/Neck_Isometrics_7
# Frames extracted and saved to: /content/drive/MyDrive/Exercise Tracking/frames/Neck Isometrics/Neck_Isometrics_1
# Frames extracted and saved to: /content/drive/MyDrive/Exercise Tracking/frames/Neck Isometrics/Neck_Isometrics_2
# Frames extracted and saved to: /content/drive/MyDrive/Exercise Tracking/frames/Neck Isometrics/Neck_Isometrics_3
# Frames extracted and saved to: /content/drive/MyDrive/Exercise Tracking/frames/Neck Isometrics/Neck_Isometrics_4
# Frames extracted and saved to: /content/drive/MyDrive/Exercise Tracking/frames/Neck Isometrics/Neck_Isometrics_5
# Frames extracted and saved to: /content/drive/MyDrive/Exercise Tracking/frames/Neck Isometrics/Neck_Isometrics_8
# Frames extracted and saved to: /content/drive/MyDrive/Exercise Tracking/frames/Neck Isometrics/Neck_Isometrics_9
# Frames extracted and saved to: /content/drive/MyDrive/Exercise Tracking/frames/Neck Flexion/Neck_Flexion_6
# Frames extracted and saved to: /content/drive/MyDrive/Exercise Tracking/frames/Neck Flexion/Neck_Flexion_7
# Frames extracted and saved to: /content/drive/MyDrive/Exercise Tracking/frames/Neck Flexion/Neck_Flexion_1
# Frames extracted and saved to: /content/drive/MyDrive/Exercise Tracking/frames/Neck Flexion/Neck_Flexion_2
# Frames extracted and saved to: /content/drive/MyDrive/Exercise Tracking/frames/Neck Flexion/Neck_Flexion_3
# Frames extracted and saved to: /content/drive/MyDrive/Exercise Tracking/frames/Neck Flexion/Neck_Flexion_4
# Frames extracted and saved to: /content/drive/MyDrive/Exercise Tracking/frames/Neck Flexion/Neck_Flexion_5
# Frames extracted and saved to: /content/drive/MyDrive/Exercise Tracking/frames/Neck Flexion/Neck_Flexion_8
# Frames extracted and saved to: /content/drive/MyDrive/Exercise Tracking/frames/Neck Flexion/Neck_Flexion_9
# Frames extracted and saved to: /content/drive/MyDrive/Exercise Tracking/frames/Neck Extension/Neck_Extension_7
# Frames extracted and saved to: /content/drive/MyDrive/Exercise Tracking/frames/Neck Extension/Neck_Extension_8
# Frames extracted and saved to: /content/drive/MyDrive/Exercise Tracking/frames/Neck Extension/Neck_Extension_1
# Frames extracted and saved to: /content/drive/MyDrive/Exercise Tracking/frames/Neck Extension/Neck_Extension_2
# Frames extracted and saved to: /content/drive/MyDrive/Exercise Tracking/frames/Neck Extension/Neck_Extension_3
# Frames extracted and saved to: /content/drive/MyDrive/Exercise Tracking/frames/Neck Extension/Neck_Extension_4
# Frames extracted and saved to: /content/drive/MyDrive/Exercise Tracking/frames/Neck Extension/Neck_Extension_5
# Frames extracted and saved to: /content/drive/MyDrive/Exercise Tracking/frames/Neck Extension/Neck_Extension_6
# Frames extracted and saved to: /content/drive/MyDrive/Exercise Tracking/frames/Neck Extension/Neck_Extension_9
# Frames extracted and saved to: /content/drive/MyDrive/Exercise Tracking/frames/Chin Tucks/Chin_Tucks_5
# Frames extracted and saved to: /content/drive/MyDrive/Exercise Tracking/frames/Chin Tucks/Chin_Tucks_6
# Frames extracted and saved to: /content/drive/MyDrive/Exercise Tracking/frames/Chin Tucks/Chin_Tucks_1
# Frames extracted and saved to: /content/drive/MyDrive/Exercise Tracking/frames/Chin Tucks/Chin_Tucks_2
# Frames extracted and saved to: /content/drive/MyDrive/Exercise Tracking/frames/Chin Tucks/Chin_Tucks_3
# Frames extracted and saved to: /content/drive/MyDrive/Exercise Tracking/frames/Chin Tucks/Chin_Tucks_4
# Frames extracted and saved to: /content/drive/MyDrive/Exercise Tracking/frames/Chin Tucks/Chin_Tucks_7
# Frames extracted and saved to: /content/drive/MyDrive/Exercise Tracking/frames/Chin Tucks/Chin_Tucks_8
# Frames extracted and saved to: /content/drive/MyDrive/Exercise Tracking/frames/Neck Rotation/Neck_Rotation_6
# Frames extracted and saved to: /content/drive/MyDrive/Exercise Tracking/frames/Neck Rotation/Neck_Rotation_7
# Frames extracted and saved to: /content/drive/MyDrive/Exercise Tracking/frames/Neck Rotation/Neck_Rotation_1
# Frames extracted and saved to: /content/drive/MyDrive/Exercise Tracking/frames/Neck Rotation/Neck_Rotation_2
# Frames extracted and saved to: /content/drive/MyDrive/Exercise Tracking/frames/Neck Rotation/Neck_Rotation_3
# Frames extracted and saved to: /content/drive/MyDrive/Exercise Tracking/frames/Neck Rotation/Neck_Rotation_4
# Frames extracted and saved to: /content/drive/MyDrive/Exercise Tracking/frames/Neck Rotation/Neck_Rotation_5
# Frames extracted and saved to: /content/drive/MyDrive/Exercise Tracking/frames/Neck Rotation/Neck_Rotation_8
# Frames extracted and saved to: /content/drive/MyDrive/Exercise Tracking/frames/Neck Rotation/Neck_Rotation_9
